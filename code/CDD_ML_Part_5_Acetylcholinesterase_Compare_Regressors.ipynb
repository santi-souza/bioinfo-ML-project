# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
# Chanin Nantasenamat
#
# ['Data Professor' YouTube channel](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In Part 5, we will be comparing several ML algorithms for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.11/site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (from lazypredict) (2.1.4)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from lazypredict) (4.65.0)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.11/site-packages (from lazypredict) (1.2.0)
# Collecting lightgbm (from lazypredict)
#   Downloading lightgbm-4.5.0-py3-none-macosx_12_0_arm64.whl.metadata (17 kB)
# Collecting xgboost (from lazypredict)
#   Downloading xgboost-2.1.1-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.17.0 in /opt/anaconda3/lib/python3.11/site-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.11/site-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->lazypredict) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn->lazypredict) (2.2.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Downloading lightgbm-4.5.0-py3-none-macosx_12_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 636.1 kB/s eta 0:00:00a 0:00:01
# Downloading xgboost-2.1.1-py3-none-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 1.1 MB/s eta 0:00:00a 0:00:010m
# Installing collected packages: xgboost, lightgbm, lazypredict
# Successfully installed lazypredict-0.2.12 lightgbm-4.5.0 xgboost-2.1.1
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ## **2. Load the data set**

# %%
! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Out:
# --2024-08-20 17:32:35--  https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2024-08-20 17:32:36--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv.2’
#
# acetylcholinesteras 100%[===================>]   7.98M   815KB/s    in 9.2s
#
# 2024-08-20 17:32:45 (888 KB/s) - ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv.2’ saved [8363909/8363909]

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (4695, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:23<00:00,  1.82it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000701 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [00:20<00:00,  2.02it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000536 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                       Adjusted R-Squared  \
# Model
# DecisionTreeRegressor                               0.79
# ExtraTreeRegressor                                  0.79
# ExtraTreesRegressor                                 0.79
# GaussianProcessRegressor                            0.79
# RandomForestRegressor                               0.74
# XGBRegressor                                        0.74
# BaggingRegressor                                    0.72
# MLPRegressor                                        0.68
# HistGradientBoostingRegressor                       0.54
# LGBMRegressor                                       0.52
# KNeighborsRegressor                                 0.50
# SVR                                                 0.41
# NuSVR                                               0.40
# GradientBoostingRegressor                           0.30
# LinearRegression                                    0.22
# TransformedTargetRegressor                          0.22
# RidgeCV                                             0.22
# Ridge                                               0.22
# ElasticNetCV                                        0.22
# LassoCV                                             0.22
# HuberRegressor                                      0.21
# BayesianRidge                                       0.20
# LassoLarsCV                                         0.19
# LassoLarsIC                                         0.19
# SGDRegressor                                        0.19
# LinearSVR                                           0.19
# PoissonRegressor                                    0.16
# OrthogonalMatchingPursuit                           0.12
# OrthogonalMatchingPursuitCV                         0.11
# GammaRegressor                                      0.11
# TweedieRegressor                                    0.11
# AdaBoostRegressor                                   0.09
# LarsCV                                              0.09
# Lasso                                              -0.04
# ElasticNet                                         -0.04
# DummyRegressor                                     -0.04
# LassoLars                                          -0.04
# PassiveAggressiveRegressor                         -0.13
# Lars                                               -2.65
# KernelRidge                                       -14.33
# RANSACRegressor               -3739282253785381994496.00
#
#                                                R-Squared           RMSE  \
# Model
# DecisionTreeRegressor                               0.80           0.69
# ExtraTreeRegressor                                  0.80           0.69
# ExtraTreesRegressor                                 0.80           0.69
# GaussianProcessRegressor                            0.80           0.69
# RandomForestRegressor                               0.75           0.77
# XGBRegressor                                        0.75           0.78
# BaggingRegressor                                    0.73           0.80
# MLPRegressor                                        0.69           0.86
# HistGradientBoostingRegressor                       0.56           1.03
# LGBMRegressor                                       0.54           1.05
# KNeighborsRegressor                                 0.52           1.08
# SVR                                                 0.43           1.17
# NuSVR                                               0.42           1.18
# GradientBoostingRegressor                           0.33           1.27
# LinearRegression                                    0.25           1.34
# TransformedTargetRegressor                          0.25           1.34
# RidgeCV                                             0.25           1.34
# Ridge                                               0.25           1.34
# ElasticNetCV                                        0.25           1.35
# LassoCV                                             0.25           1.35
# HuberRegressor                                      0.24           1.36
# BayesianRidge                                       0.23           1.36
# LassoLarsCV                                         0.22           1.37
# LassoLarsIC                                         0.22           1.37
# SGDRegressor                                        0.22           1.37
# LinearSVR                                           0.22           1.37
# PoissonRegressor                                    0.20           1.39
# OrthogonalMatchingPursuit                           0.15           1.43
# OrthogonalMatchingPursuitCV                         0.15           1.43
# GammaRegressor                                      0.14           1.44
# TweedieRegressor                                    0.14           1.44
# AdaBoostRegressor                                   0.13           1.45
# LarsCV                                              0.12           1.45
# Lasso                                               0.00           1.55
# ElasticNet                                          0.00           1.55
# DummyRegressor                                      0.00           1.55
# LassoLars                                           0.00           1.55
# PassiveAggressiveRegressor                         -0.08           1.62
# Lars                                               -2.52           2.91
# KernelRidge                                       -13.78           5.97
# RANSACRegressor               -3602855710837685878784.00 93184820725.75
#
#                                Time Taken
# Model
# DecisionTreeRegressor                0.06
# ExtraTreeRegressor                   0.07
# ExtraTreesRegressor                  2.75
# GaussianProcessRegressor             1.97
# RandomForestRegressor                1.87
# XGBRegressor                         0.35
# BaggingRegressor                     0.19
# MLPRegressor                         3.61
# HistGradientBoostingRegressor        0.50
# LGBMRegressor                        0.15
# KNeighborsRegressor                  0.18
# SVR                                  1.87
# NuSVR                                1.33
# GradientBoostingRegressor            0.81
# LinearRegression                     0.03
# TransformedTargetRegressor           0.04
# RidgeCV                              0.05
# Ridge                                0.01
# ElasticNetCV                         2.19
# LassoCV                              2.29
# HuberRegressor                       0.20
# BayesianRidge                        0.06
# LassoLarsCV                          0.12
# LassoLarsIC                          0.06
# SGDRegressor                         0.07
# LinearSVR                            0.38
# PoissonRegressor                     0.14
# OrthogonalMatchingPursuit            0.02
# OrthogonalMatchingPursuitCV          0.07
# GammaRegressor                       0.06
# TweedieRegressor                     0.07
# AdaBoostRegressor                    0.20
# LarsCV                               0.14
# Lasso                                0.04
# ElasticNet                           0.03
# DummyRegressor                       0.02
# LassoLars                            0.02
# PassiveAggressiveRegressor           0.05
# Lars                                 0.05
# KernelRidge                          0.38
# RANSACRegressor                      0.55

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                       Adjusted R-Squared  \
# Model
# HistGradientBoostingRegressor                       0.25
# LGBMRegressor                                       0.24
# XGBRegressor                                        0.22
# RandomForestRegressor                               0.21
# KNeighborsRegressor                                 0.20
# NuSVR                                               0.18
# BaggingRegressor                                    0.17
# SVR                                                 0.17
# MLPRegressor                                        0.14
# GradientBoostingRegressor                           0.13
# LassoCV                                             0.06
# ElasticNetCV                                        0.06
# BayesianRidge                                       0.05
# Ridge                                               0.05
# RidgeCV                                             0.05
# LassoLarsIC                                         0.05
# LassoLarsCV                                         0.05
# TransformedTargetRegressor                          0.05
# LinearRegression                                    0.05
# PoissonRegressor                                    0.03
# SGDRegressor                                        0.03
# HuberRegressor                                      0.03
# LinearSVR                                          -0.00
# OrthogonalMatchingPursuit                          -0.02
# OrthogonalMatchingPursuitCV                        -0.02
# TweedieRegressor                                   -0.02
# GammaRegressor                                     -0.03
# ExtraTreesRegressor                                -0.03
# LarsCV                                             -0.05
# AdaBoostRegressor                                  -0.05
# DecisionTreeRegressor                              -0.05
# ExtraTreeRegressor                                 -0.08
# Lasso                                              -0.17
# ElasticNet                                         -0.17
# DummyRegressor                                     -0.17
# LassoLars                                          -0.17
# PassiveAggressiveRegressor                         -0.26
# Lars                                               -2.97
# GaussianProcessRegressor                           -6.78
# KernelRidge                                       -16.61
# RANSACRegressor               -3204532560108998098944.00
#
#                                                R-Squared           RMSE  \
# Model
# HistGradientBoostingRegressor                       0.36           1.24
# LGBMRegressor                                       0.35           1.25
# XGBRegressor                                        0.34           1.27
# RandomForestRegressor                               0.33           1.27
# KNeighborsRegressor                                 0.31           1.29
# NuSVR                                               0.30           1.30
# BaggingRegressor                                    0.29           1.30
# SVR                                                 0.29           1.31
# MLPRegressor                                        0.27           1.33
# GradientBoostingRegressor                           0.26           1.34
# LassoCV                                             0.19           1.39
# ElasticNetCV                                        0.19           1.39
# BayesianRidge                                       0.19           1.40
# Ridge                                               0.19           1.40
# RidgeCV                                             0.19           1.40
# LassoLarsIC                                         0.19           1.40
# LassoLarsCV                                         0.19           1.40
# TransformedTargetRegressor                          0.19           1.40
# LinearRegression                                    0.19           1.40
# PoissonRegressor                                    0.17           1.42
# SGDRegressor                                        0.17           1.42
# HuberRegressor                                      0.17           1.42
# LinearSVR                                           0.14           1.44
# OrthogonalMatchingPursuit                           0.13           1.45
# OrthogonalMatchingPursuitCV                         0.12           1.45
# TweedieRegressor                                    0.12           1.45
# GammaRegressor                                      0.12           1.45
# ExtraTreesRegressor                                 0.12           1.46
# LarsCV                                              0.10           1.47
# AdaBoostRegressor                                   0.10           1.47
# DecisionTreeRegressor                               0.10           1.47
# ExtraTreeRegressor                                  0.08           1.49
# Lasso                                              -0.00           1.55
# ElasticNet                                         -0.00           1.55
# DummyRegressor                                     -0.00           1.55
# LassoLars                                          -0.00           1.55
# PassiveAggressiveRegressor                         -0.08           1.61
# Lars                                               -2.39           2.86
# GaussianProcessRegressor                           -5.64           4.00
# KernelRidge                                       -14.03           6.02
# RANSACRegressor               -2736493156340413235200.00 81245892603.06
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        0.73
# LGBMRegressor                        0.10
# XGBRegressor                         0.32
# RandomForestRegressor                1.87
# KNeighborsRegressor                  0.11
# NuSVR                                0.82
# BaggingRegressor                     0.19
# SVR                                  1.08
# MLPRegressor                         2.82
# GradientBoostingRegressor            0.85
# LassoCV                              2.31
# ElasticNetCV                         2.12
# BayesianRidge                        0.04
# Ridge                                0.03
# RidgeCV                              0.20
# LassoLarsIC                          0.06
# LassoLarsCV                          0.11
# TransformedTargetRegressor           0.03
# LinearRegression                     0.05
# PoissonRegressor                     0.09
# SGDRegressor                         0.05
# HuberRegressor                       0.31
# LinearSVR                            0.40
# OrthogonalMatchingPursuit            0.02
# OrthogonalMatchingPursuitCV          0.04
# TweedieRegressor                     0.04
# GammaRegressor                       0.04
# ExtraTreesRegressor                  2.70
# LarsCV                               0.12
# AdaBoostRegressor                    0.22
# DecisionTreeRegressor                0.06
# ExtraTreeRegressor                   0.07
# Lasso                                0.02
# ElasticNet                           0.03
# DummyRegressor                       0.02
# LassoLars                            0.02
# PassiveAggressiveRegressor           0.03
# Lars                                 0.04
# GaussianProcessRegressor             1.77
# KernelRidge                          0.45
# RANSACRegressor                      0.39

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
